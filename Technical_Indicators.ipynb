# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ticker = ["ADANIENT.NS"]

# %%
ADANI = yf.download(ticker,start="2015-01-01",end="2025-04-20")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
ADANI
# Out:
# Price             Close         High          Low         Open      Volume
# Ticker      ADANIENT.NS  ADANIENT.NS  ADANIENT.NS  ADANIENT.NS ADANIENT.NS
# Date
# 2015-01-01    70.628403    70.995961    69.273495    69.965363     3946806
# 2015-01-02    70.974335    71.637375    70.628394    70.815782     6565229
# 2015-01-05    72.149078    73.013913    70.729305    70.786960     9404837
# 2015-01-06    71.601349    74.649902    69.792399    71.435592    18412441
# 2015-01-07    70.967148    73.158070    69.475304    72.069816    10863352
# ...                 ...          ...          ...          ...         ...
# 2025-04-09  2236.899902  2279.550049  2215.199951  2265.699951     1001633
# 2025-04-11  2321.399902  2343.500000  2281.000000  2303.050049      981463
# 2025-04-15  2418.199951  2440.000000  2359.000000  2375.000000     1145125
# 2025-04-16  2415.600098  2428.000000  2382.899902  2400.000000      889949
# ...

# %%
adani = ADANI.loc[:, "Close"]

adani
# Out:
# Ticker      ADANIENT.NS
# Date
# 2015-01-01    70.628403
# 2015-01-02    70.974335
# 2015-01-05    72.149078
# 2015-01-06    71.601349
# 2015-01-07    70.967148
# ...                 ...
# 2025-04-09  2236.899902
# 2025-04-11  2321.399902
# 2025-04-15  2418.199951
# 2025-04-16  2415.600098
# 2025-04-17  2418.100098
#
# [2540 rows x 1 columns]

# %%
adani
# Out:
# Ticker      ADANIENT.NS
# Date
# 2015-01-01    70.628403
# 2015-01-02    70.974335
# 2015-01-05    72.149078
# 2015-01-06    71.601349
# 2015-01-07    70.967148
# ...                 ...
# 2025-04-09  2236.899902
# 2025-04-11  2321.399902
# 2025-04-15  2418.199951
# 2025-04-16  2415.600098
# 2025-04-17  2418.100098
#
# [2540 rows x 1 columns]

# %%
adani.plot(figsize=(12,8),fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
adani.plot(figsize=(12,8),fontsize=12)
plt.show()

# %%
#calculation mean median and max
adaniroll = adani.rolling(window=10).mean()
adaniroll.head(15)
# Out:
# Ticker      ADANIENT.NS
# Date
# 2015-01-01          NaN
# 2015-01-02          NaN
# 2015-01-05          NaN
# 2015-01-06          NaN
# 2015-01-07          NaN
# 2015-01-08          NaN
# 2015-01-09          NaN
# 2015-01-12          NaN
# 2015-01-13          NaN
# 2015-01-14    71.969627
# 2015-01-15    72.126739
# 2015-01-16    72.240610
# 2015-01-19    72.323491
# 2015-01-20    72.464027
# 2015-01-21    72.662940

# %%
adanimedian = adani.rolling(window=10).median()
adanimedian.head(15)
# Out:
# Ticker      ADANIENT.NS
# Date
# 2015-01-01          NaN
# 2015-01-02          NaN
# 2015-01-05          NaN
# 2015-01-06          NaN
# 2015-01-07          NaN
# 2015-01-08          NaN
# 2015-01-09          NaN
# 2015-01-12          NaN
# 2015-01-13          NaN
# 2015-01-14    71.597748
# 2015-01-15    71.875214
# 2015-01-16    72.131062
# 2015-01-19    72.156284
# 2015-01-20    72.588707
# 2015-01-21    72.967083

# %%
adanimax = adani.rolling(window=10).max()
adanimax.head(15)
# Out:
# Ticker      ADANIENT.NS
# Date
# 2015-01-01          NaN
# 2015-01-02          NaN
# 2015-01-05          NaN
# 2015-01-06          NaN
# 2015-01-07          NaN
# 2015-01-08          NaN
# 2015-01-09          NaN
# 2015-01-12          NaN
# 2015-01-13          NaN
# 2015-01-14    74.167038
# 2015-01-15    74.167038
# 2015-01-16    74.167038
# 2015-01-19    74.167038
# 2015-01-20    74.167038
# 2015-01-21    74.167038

# %%
adanimax
# Out:
# Ticker      ADANIENT.NS
# Date
# 2015-01-01          NaN
# 2015-01-02          NaN
# 2015-01-05          NaN
# 2015-01-06          NaN
# 2015-01-07          NaN
# ...                 ...
# 2025-04-09  2410.800049
# 2025-04-11  2410.800049
# 2025-04-15  2418.199951
# 2025-04-16  2418.199951
# 2025-04-17  2418.199951
#
# [2540 rows x 1 columns]

# %%
adani["SMA50"] = adani["ADANIENT.NS"].rolling(window=50).mean()
adani
# Out:
# <ipython-input-14-677daf318baf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adani["SMA50"] = adani["ADANIENT.NS"].rolling(window=50).mean()
# Ticker      ADANIENT.NS        SMA50
# Date
# 2015-01-01    70.628403          NaN
# 2015-01-02    70.974335          NaN
# 2015-01-05    72.149078          NaN
# 2015-01-06    71.601349          NaN
# 2015-01-07    70.967148          NaN
# ...                 ...          ...
# 2025-04-09  2236.899902  2260.974019
# 2025-04-11  2321.399902  2261.681016
# 2025-04-15  2418.199951  2263.673013
# 2025-04-16  2415.600098  2266.933013
# 2025-04-17  2418.100098  2269.539014
#
# [2540 rows x 2 columns]

# %%
adani.plot(figsize =(12,8),fontsize=12)
plt.legend(loc="upper left",fontsize=12)
plt.show()

# %%
adani["EMA200"] = adani["ADANIENT.NS"].ewm(span=200).mean()
# Out:
# <ipython-input-16-8de754628985>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adani["EMA200"] = adani["ADANIENT.NS"].ewm(span=200).mean()

# %%
adani
# Out:
# Ticker      ADANIENT.NS        SMA50       EMA200
# Date
# 2015-01-01    70.628403          NaN    70.628403
# 2015-01-02    70.974335          NaN    70.802234
# 2015-01-05    72.149078          NaN    71.255679
# 2015-01-06    71.601349          NaN    71.343397
# 2015-01-07    70.967148          NaN    71.266635
# ...                 ...          ...          ...
# 2025-04-09  2236.899902  2260.974019  2575.365710
# 2025-04-11  2321.399902  2261.681016  2572.838687
# 2025-04-15  2418.199951  2263.673013  2571.299994
# 2025-04-16  2415.600098  2266.933013  2569.750741
# 2025-04-17  2418.100098  2269.539014  2568.241779
#
# [2540 rows x 3 columns]

# %%
adani.plot(figsize =(12,8),fontsize=12)
plt.legend(loc="upper left",fontsize=12)
plt.show()

# %% [markdown]
# #CUMMALTIVE RETURNS,Drawdowns etc

# %%
reliance = yf.download("RELIANCE.NS")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
reliance
# Out:
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 1996-01-01     6.069189     6.079513     6.007243     6.047066   104121369
# 1996-01-02     6.021993     6.083939     5.977746     6.054441   168743308
# 1996-01-03     6.067715     6.399566     6.054441     6.120811   209323879
# 1996-01-04     6.011668     6.029367     5.930549     6.010193   216900264
# 1996-01-05     5.970371     5.988070     5.918750     5.988070   166708467
# ...                 ...          ...          ...          ...         ...
# 2025-04-21  1295.500000  1300.900024  1267.000000  1270.000000    10429964
# 2025-04-22  1291.199951  1303.900024  1286.300049  1300.000000    13051707
# 2025-04-23  1300.000000  1306.000000  1285.400024  1297.000000    10480888
# 2025-04-24  1301.599976  1304.500000  1290.300049  1292.400024    10468940
# ...

# %%
reliance.columns
# Out:
# MultiIndex([( 'Close', 'RELIANCE.NS'),
#             (  'High', 'RELIANCE.NS'),
#             (   'Low', 'RELIANCE.NS'),
#             (  'Open', 'RELIANCE.NS'),
#             ('Volume', 'RELIANCE.NS')],
#            names=['Price', 'Ticker'])

# %%
# chnaging from multindex to flatindex
reliance.columns = reliance.columns.droplevel('Ticker')
reliance
# Out:
# Price             Close         High          Low         Open     Volume
# Date
# 1996-01-01     6.069189     6.079513     6.007243     6.047066  104121369
# 1996-01-02     6.021993     6.083939     5.977746     6.054441  168743308
# 1996-01-03     6.067715     6.399566     6.054441     6.120811  209323879
# 1996-01-04     6.011668     6.029367     5.930549     6.010193  216900264
# 1996-01-05     5.970371     5.988070     5.918750     5.988070  166708467
# ...                 ...          ...          ...          ...        ...
# 2025-04-21  1295.500000  1300.900024  1267.000000  1270.000000   10429964
# 2025-04-22  1291.199951  1303.900024  1286.300049  1300.000000   13051707
# 2025-04-23  1300.000000  1306.000000  1285.400024  1297.000000   10480888
# 2025-04-24  1301.599976  1304.500000  1290.300049  1292.400024   10468940
# 2025-04-25  1300.400024  1325.199951  1288.099976  1303.500000   14422621
#
# [7359 rows x 5 columns]

# %%
reliance.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')

# %%
#copy the close column from reliance to rel
rel = reliance.loc[:, "Close"]
rel
# Out:
# Date
# 1996-01-01       6.069189
# 1996-01-02       6.021993
# 1996-01-03       6.067715
# 1996-01-04       6.011668
# 1996-01-05       5.970371
#                  ...
# 2025-04-21    1295.500000
# 2025-04-22    1291.199951
# 2025-04-23    1300.000000
# 2025-04-24    1301.599976
# 2025-04-25    1300.400024
# Name: Close, Length: 7359, dtype: float64

# %%
rel
# Out:
# Date
# 1996-01-01       6.069189
# 1996-01-02       6.021993
# 1996-01-03       6.067715
# 1996-01-04       6.011668
# 1996-01-05       5.970371
#                  ...
# 2025-04-21    1295.500000
# 2025-04-22    1291.199951
# 2025-04-23    1300.000000
# 2025-04-24    1301.599976
# 2025-04-25    1300.400024
# Name: Close, Length: 7359, dtype: float64

# %%
rel = rel.to_frame()
rel.head()
# Out:
#                Close
# Date
# 1996-01-01  6.069189
# 1996-01-02  6.021993
# 1996-01-03  6.067715
# 1996-01-04  6.011668
# 1996-01-05  5.970371

# %%
rel["d-returns"] = np.log(rel.div(rel.shift(1)))
rel
# Out:
#                   Close  d-returns
# Date
# 1996-01-01     6.069189        NaN
# 1996-01-02     6.021993  -0.007807
# 1996-01-03     6.067715   0.007564
# 1996-01-04     6.011668  -0.009280
# 1996-01-05     5.970371  -0.006893
# ...                 ...        ...
# 2025-04-21  1295.500000   0.016343
# 2025-04-22  1291.199951  -0.003325
# 2025-04-23  1300.000000   0.006792
# 2025-04-24  1301.599976   0.001230
# 2025-04-25  1300.400024  -0.000922
#
# [7359 rows x 2 columns]

# %%
rel.dropna(inplace=True)
rel
# Out:
#                   Close  d-returns
# Date
# 1996-01-02     6.021993  -0.007807
# 1996-01-03     6.067715   0.007564
# 1996-01-04     6.011668  -0.009280
# 1996-01-05     5.970371  -0.006893
# 1996-01-08     5.731437  -0.040843
# ...                 ...        ...
# 2025-04-21  1295.500000   0.016343
# 2025-04-22  1291.199951  -0.003325
# 2025-04-23  1300.000000   0.006792
# 2025-04-24  1301.599976   0.001230
# 2025-04-25  1300.400024  -0.000922
#
# [7358 rows x 2 columns]

# %%
rel["d-returns"].sum()
# Out:
# np.float64(5.367202285727163)

# %%
np.exp(rel["d-returns"].sum())
# Out:
# np.float64(214.26258289688897)

# %%
rel["cum-returns"] = rel["d-returns"].cumsum().apply(np.exp)

# %%
rel.head(5000)
# Out:
#                  Close  d-returns  cum-returns
# Date
# 1996-01-02    6.021993  -0.007807     0.992224
# 1996-01-03    6.067715   0.007564     0.999757
# 1996-01-04    6.011668  -0.009280     0.990522
# 1996-01-05    5.970371  -0.006893     0.983718
# 1996-01-08    5.731437  -0.040843     0.944350
# ...                ...        ...          ...
# 2015-09-24  183.543900  -0.015406    30.241917
# 2015-09-28  182.864365  -0.003709    30.129953
# 2015-09-29  184.289139   0.007761    30.364708
# 2015-09-30  189.012817   0.025309    31.143013
# 2015-10-01  189.538895   0.002779    31.229693
#
# [5000 rows x 3 columns]

# %%
rel["cum-returns"].plot(figsize=(12,8),title="Growth of 1 rupee in reliance over the years",fontsize=12)
# Out:
# <Axes: title={'center': 'Growth of 1 rupee in reliance over the years'}, xlabel='Date'>

# %%
# now calculating annual average returns percent of reliance since
rel["d-returns"].mean()*252*100
# Out:
# np.float64(18.38182897530912)

# %%
# now risk factor percent
rel["d-returns"].std()*np.sqrt(252)*100
# Out:
# np.float64(54.767722447248865)

# %%
#how to calculate drawdowns
rel["cummmax"] = rel['cum-returns'].cummax()
rel
# Out:
#                   Close  d-returns  cum-returns     cummmax
# Date
# 1996-01-02     6.021993  -0.007807     0.992224    0.992224
# 1996-01-03     6.067715   0.007564     0.999757    0.999757
# 1996-01-04     6.011668  -0.009280     0.990522    0.999757
# 1996-01-05     5.970371  -0.006893     0.983718    0.999757
# 1996-01-08     5.731437  -0.040843     0.944350    0.999757
# ...                 ...        ...          ...         ...
# 2025-04-21  1295.500000   0.016343   213.455222  262.882750
# 2025-04-22  1291.199951  -0.003325   212.746717  262.882750
# 2025-04-23  1300.000000   0.006792   214.196672  262.882750
# 2025-04-24  1301.599976   0.001230   214.460295  262.882750
# 2025-04-25  1300.400024  -0.000922   214.262583  262.882750
#
# [7358 rows x 4 columns]

# %%
rel[["cum-returns","cummmax"]].plot(figsize=(12,8),title="Reliance buy and hold+cummmax",fontsize=12)
# Out:
# <Axes: title={'center': 'Reliance buy and hold+cummmax'}, xlabel='Date'>

# %%
rel["drawdown"] = rel['cummmax']-rel['cum-returns']
rel
# Out:
#                   Close  d-returns  cum-returns     cummmax   drawdown
# Date
# 1996-01-02     6.021993  -0.007807     0.992224    0.992224   0.000000
# 1996-01-03     6.067715   0.007564     0.999757    0.999757   0.000000
# 1996-01-04     6.011668  -0.009280     0.990522    0.999757   0.009235
# 1996-01-05     5.970371  -0.006893     0.983718    0.999757   0.016039
# 1996-01-08     5.731437  -0.040843     0.944350    0.999757   0.055407
# ...                 ...        ...          ...         ...        ...
# 2025-04-21  1295.500000   0.016343   213.455222  262.882750  49.427527
# 2025-04-22  1291.199951  -0.003325   212.746717  262.882750  50.136032
# 2025-04-23  1300.000000   0.006792   214.196672  262.882750  48.686077
# 2025-04-24  1301.599976   0.001230   214.460295  262.882750  48.422455
# 2025-04-25  1300.400024  -0.000922   214.262583  262.882750  48.620167
#
# [7358 rows x 5 columns]

# %%
rel['drawdown'].max()
# Out:
# 71.44035057794974

# %%
rel.drawdown.idxmax()
# Out:
# Timestamp('2025-03-04 00:00:00')

# %%
rel.loc[(rel.index=='2025-03-04')]
# Out:
#                   Close  d-returns  cum-returns    cummmax   drawdown
# Date
# 2025-03-04  1161.900024  -0.008015   191.442399  262.88275  71.440351

# %%
#now calculate drowdown percentage
rel['drawdown%'] = (rel["cummmax"]-rel['cum-returns'])/rel['cummmax']*100

# %%
rel
# Out:
#                   Close  d-returns  cum-returns     cummmax   drawdown  \
# Date
# 1996-01-02     6.021993  -0.007807     0.992224    0.992224   0.000000
# 1996-01-03     6.067715   0.007564     0.999757    0.999757   0.000000
# 1996-01-04     6.011668  -0.009280     0.990522    0.999757   0.009235
# 1996-01-05     5.970371  -0.006893     0.983718    0.999757   0.016039
# 1996-01-08     5.731437  -0.040843     0.944350    0.999757   0.055407
# ...                 ...        ...          ...         ...        ...
# 2025-04-21  1295.500000   0.016343   213.455222  262.882750  49.427527
# 2025-04-22  1291.199951  -0.003325   212.746717  262.882750  50.136032
# 2025-04-23  1300.000000   0.006792   214.196672  262.882750  48.686077
# 2025-04-24  1301.599976   0.001230   214.460295  262.882750  48.422455
# 2025-04-25  1300.400024  -0.000922   214.262583  262.882750  48.620167
#
#             drawdown%
# Date
# 1996-01-02   0.000000
# 1996-01-03   0.000000
# 1996-01-04   0.923699
# ...

# %%
rel['drawdown%'].max()
# Out:
# 77.58978891612817

# %%
rel["drawdown%"].idxmax()
# Out:
# Timestamp('2005-08-23 00:00:00')
